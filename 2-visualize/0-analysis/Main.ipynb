# %%
import pandas as pd
from scipy.stats import chi2_contingency
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('CLEAN.csv')
df = df.drop(columns=['Note'])
df
# Out:
#      Gender   Race Residence  Income School Type Hooks         Major   SAT  \
# 0         M  ASIAN        MI     Low          -1  NONE            CS  1440
# 1     OTHER  ASIAN        IN    High          -1  NONE            CS  1390
# 2         F  ASIAN        MA    High      PUBLIC  NONE  NEUROSCIENCE  1580
# 3         M  WHITE        IN     Low          -1   URM            CS  1580
# 4         F  ASIAN        OR  Middle      PUBLIC  NONE            CS  1580
# ...     ...    ...       ...     ...         ...   ...           ...   ...
# 1479      M  ASIAN        GA  Middle      PUBLIC  LGBT           BIO  1580
# 1480      F  ASIAN        CA    High      PUBLIC  NONE            CS  1590
# 1481      M  ASIAN        CA  Middle      PUBLIC  NONE           ENG  1240
# 1482      M  ASIAN        CA     Low      PUBLIC  NONE            CS  1580
# 1483      M  ASIAN        FL    High      PUBLIC  NONE            CS  1560
#
#       EC-AWARDS  ESSAY-LOR-INTERVIEW  \
# 0           2.0                  4.5
# 1           5.5                  4.5
# 2           7.5                  7.5
# 3           5.5                  1.5
# 4           7.5                  4.7
# ...         ...                  ...
# 1479        5.0                  3.5
# 1480        7.5                  3.5
# 1481        3.0                  6.5
# 1482        6.5                  7.5
# 1483        8.5                  8.5
#
#                                             Acceptances  \
# 0                                           ['*PURDUE']
# 1                                         ['*STANFORD']
# 2     ['*UCLA', '*HARVARD', '*YALE', '*COLUMBIA', '*...
# 3     ['*GEORGIA TECH', '*UT-AUSTIN', '*ARIZONA STAT...
# 4                              ['*CORNELL', '*RUTGERS']
# ...                                                 ...
# 1479                         ['*NYU', '*UMICH', '*USC']
# 1480       ['*DUKE', '*UCSD', '*UIUC', '*NORTHEASTERN']
# 1481                                           ['*UCI']
# 1482  ['*UCLA', '*PURDUE', '*POMONA', '*ARIZONA STAT...
# 1483  ['*UCLA', '*UCSD', '*GEORGIA TECH', '*PURDUE',...
#
#                                               Waitlists  \
# 0                           ['*GEORGIA TECH', '*UMICH']
# 1                                                    []
# 2                                            ['*UPENN']
# 3                             ['*HARVARD', '*UCHICAGO']
# 4                                                    []
# ...                                                 ...
# 1479                    ['*JOHNS HOPKINS', '*UCHICAGO']
# 1480                          ['*CMU', '*UCSB', '*UCI']
# 1481                                        ['*POMONA']
# 1482  ['*UCLA', '*STANFORD', '*CORNELL', '*GEORGIA T...
# 1483  ['*COLUMBIA', '*CORNELL', '*BERKELEY', '*PRINC...
#
#                                              Rejections
# 0                            ['*UIUC', '*NORTHEASTERN']
# 1                                          ['*CALTECH']
# 2                            ['*STANFORD', '*COLUMBIA']
# 3     ['*UCLA', '*NORTHWESTERN', '*UMICH', '*EMORY',...
# 4                                          ['*CORNELL']
# ...                                                 ...
# 1479  ['*HARVARD', '*YALE', '*BROWN', '*STANFORD', '...
# 1480  ['*UCLA', '*HARVARD', '*BROWN', '*STANFORD', '...
# 1481                             ['*UCLA', '*BERKELEY']
# 1482  ['*HARVARD', '*YALE', '*COLUMBIA', '*MIT', '*C...
# 1483      ['*HARVARD', '*STANFORD', '*MIT', '*CALTECH']
#
# [1484 rows x 13 columns]

# %%
colleges = [ '*UCLA', '*HARVARD', '*YALE'
, '*STANFORD', '*NORTHWESTERN', '*COLUMBIA', '*CORNELL', '*BERKELEY'
, '*DUKE', '*PRINCETON', '*UCSD', '*MIT', '*CALTECH', '*GEORGIA TECH'
, '*JOHNS HOPKINS', '*SWARTHMORE', '*DARTMOUTH', '*CMU', '*PURDUE'
, '*RICE', '*POMONA', '*WILLIAMS', '*VANDERBILT', '*NYU', '*UPENN'
, '*UMICH', '*EMORY', '*CASE WESTERN', '*USC', '*UCSB', '*UCD', '*UCSC'
, '*UCR', '*UIUC', '*BOSTON UNIVERSITY', '*BOSTON COLLEGE', '*WASHU'
, '*UT-AUSTIN', '*UT-DALLAS', '*FORDHAM', '*RUTGERS', '*San Jose State University'
, '*VIRGINIA TECH', '*NORTHEASTERN', '*COLGATE', '*UW MADISON'
, '*TUFTS', '*TULANE', '*HARVEY MUDD', '*UCHICAGO', '*UNC CHAPEL HILL'
, '*UVA', '*CLAREMONT MCKENNA', '*ARIZONA STATE', '*TAMU', '*UCI', '*UCM']
# *BROWN
# *STANFORD
# *NORTHWESTERN
# *COLUMBIA
# *CORNELL
# *BERKELEY
# *DUKE
# *PRINCETON
# *UCSD
# *MIT
# *CALTECH
# *GEORGIA TECH
# *JOHNS HOPKINS
# *SWARTHMORE
# *DARTMOUTH
# *CMU
# *PURDUE
# *RICE
# *POMONA
# *WILLIAMS
# *VANDERBILT
# *NYU
# *UPENN
# *UMICH
# *EMORY
# *CASE WESTERN
# *USC
# *UCSB
# *UCD
# *UCSC
# *UCR
# *UIUC
# *BOSTON UNIVERSITY
# *BOSTON COLLEGE
# *WASHU
# *UT-AUSTIN
# *UT-DALLAS
# *FORDHAM
# *RUTGERS
# *San Jose State University
# *VIRGINIA TECH
# *NORTHEASTERN
# *COLGATE
# *UW MADISON
# *TUFTS
# *TULANE
# *HARVEY MUDD
# *UCHICAGO
# *UNC CHAPEL HILL
# *UVA
# *CLAREMONT MCKENNA
# *ARIZONA STATE
# *TAMU
# *UCI
# *UCM

# %%
def basicAnalysis(df, college):
    
    ret = []
    ret.append(college)
    ret.append(len(df))

    accepted = df[df['Decision'] == 0]
    waitlist = df[df['Decision'] == 1]
    rejected = df[df['Decision'] == 2]

    return [college, len(df), len(accepted), len(waitlist), len(rejected), 
            accepted['SAT'].mean(), waitlisted['SAT'].mean(), rejected['SAT'].mean(), 
            accepted['EC-AWARDS'].mean(), waitlist['EC-AWARDS'].mean(), rejected['EC-AWARDS'].mean(), 
            accepted['ESSAY-LOR-INTERVIEW'].mean(), waitlist['ESSAY-LOR-INTERVIEW'].mean(), rejected['ESSAY-LOR-INTERVIEW'].mean(), 
            0, 0, 0, 0, 0, 0, 0, 0, 0]
    #return ['School', 'Applications', 'Acceptances', 'Waitlists', 'Rejections', 'AcceptedSATAvg', 'WaitlistedSATAvg', 'RejectedSATAvg', 'AcceptedECAvg', 'WaitlistedECAvg', 'RejectedECAvg', 'AcceptedEssayAvg', 'WaitlistedEssayAvg', 'RejectedEssayAvg']

# %%
def getNumericalCorrelations(df, college, overall_df):
    # Correlation matrix for NUMBER rows
    corr_matrix = df[['SAT', 'EC-AWARDS', 'ESSAY-LOR-INTERVIEW']].corr()
    sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
    plt.title(str(college) + " Correlation Matrix")
    plt.savefig(f"res/{college}/"+str(college) + " Correlation Matrix.png")
    plt.close()

    
    #add the correlation matrix to the overalldf
    mask = overall_df['School'] == college
    if mask.sum() == 1:
        overall_df.loc[mask, 'COR-SAT-EC'] = corr_matrix['SAT']['EC-AWARDS']
        overall_df.loc[mask, 'COR-SAT-ESSAY'] = corr_matrix['SAT']['ESSAY-LOR-INTERVIEW']
        overall_df.loc[mask, 'COR-EC-ESSAY'] = corr_matrix['EC-AWARDS']['ESSAY-LOR-INTERVIEW']
        # print(overall_df[mask])
    else:
        print(f"Error: Found {mask.sum()} rows for {college}")

    return overall_df

# %%
def catagoricalCorrelations(df, college, overall_df):

    # Chi-square test fAGAINST the Decision
    for col in ['Gender', 'Race', 'Residence', 'School Type', 'Hooks', 'Major']:
        contingency_table = pd.crosstab(df[col], df['Decision'])

        chi2, p, _, _ = chi2_contingency(contingency_table)
        print(f'{col} - p-value: {p}')


        mask = overall_df['School'] == college
        if mask.sum() == 1:
            overall_df.loc[mask, f'pval-{col}'] = {p}


    return overall_df

# %%
overall_df = pd.DataFrame(columns=['School', 'Applications', 'Acceptances', 'Waitlists', 'Rejections', 
                                   'AcceptedSATAvg', 'WaitlistedSATAvg', 'RejectedSATAvg', 
                                   'AcceptedECAvg', 'WaitlistedECAvg', 'RejectedECAvg', 
                                   'AcceptedEssayAvg', 'WaitlistedEssayAvg', 'RejectedEssayAvg',
                                   
                                   #correlations
                                    'COR-SAT-EC', 'COR-SAT-ESSAY', 'COR-EC-ESSAY',

                                    #catagorical correlations
                                    'pval-Gender', 'pval-Race', 'pval-Residence', 'pval-School Type', 'pval-Hooks', 'pval-Major'
                                   ])

                                   

for college in colleges:
    college = college.removeprefix('*')
    
    accepted = df[df['Acceptances'].str.contains(college, regex=False)]
    accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
    accepted['Decision'] = 0

    rejected = df[df['Rejections'].str.contains(college, regex=False)]
    rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
    rejected['Decision'] = 2
    
    waitlisted = df[df['Waitlists'].str.contains(college, regex=False)]
    waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
    waitlisted['Decision'] = 1

    college_df = pd.concat([accepted, rejected, waitlisted])

    
    #create folder if it doesnt exist
    import os
    if not os.path.exists(f'res/{college}'):
        os.makedirs(f'res/{college}')


    #basic analysis
    overall_df = pd.concat([overall_df, pd.DataFrame([basicAnalysis(college_df, college)], columns=overall_df.columns)], ignore_index=True)

    #correlations between features
    overall_df = getNumericalCorrelations(college_df, college, overall_df)
    overall_df = catagoricalCorrelations(college_df, college, overall_df)

    
    # save the dataset
    college_df.to_csv(f'res/{college}/dataset.csv', index=False)
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:40: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   overall_df = pd.concat([overall_df, pd.DataFrame([basicAnalysis(college_df, college)], columns=overall_df.columns)], ignore_index=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# Gender - p-value: 0.17347857919743745
# Race - p-value: 0.7186090880560159
# Residence - p-value: 0.4712126148526475
# School Type - p-value: 0.33903650126502116
# Hooks - p-value: 0.4213690400108201
# Major - p-value: 0.11917239950270872
# Gender - p-value: 0.5381453938691496
# Race - p-value: 0.05055003905776786
# Residence - p-value: 0.011441967162762726
# School Type - p-value: 0.8912675965555017
# Hooks - p-value: 0.015057192373553827
# Major - p-value: 0.6264421115451353
# Gender - p-value: 0.0034708386085071344
# Race - p-value: 0.15507107919903979
# Residence - p-value: 0.9981974135424317
# School Type - p-value: 0.3447113188617562
# Hooks - p-value: 0.004352900644245513
# Major - p-value: 0.9918697792801817
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# Gender - p-value: 0.008791793880671736
# Race - p-value: 0.2644214871220135
# Residence - p-value: 0.6539058331344072
# School Type - p-value: 0.9834656421660932
# Hooks - p-value: 0.023060097662893176
# Major - p-value: 0.5990256483325999
# Gender - p-value: 0.7437779455117788
# Race - p-value: 1.9585648286494958e-05
# Residence - p-value: 0.07110811431944784
# School Type - p-value: 0.26198456948174825
# Hooks - p-value: 0.00015184857523332105
# Major - p-value: 0.030056908411837287
# Gender - p-value: 0.37021041566748714
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# Race - p-value: 0.10157324701113779
# Residence - p-value: 0.7888897908577736
# School Type - p-value: 0.36071421969731476
# Hooks - p-value: 0.031193940017445118
# Major - p-value: 0.5123200494329931
# Gender - p-value: 0.4432628106323325
# Race - p-value: 0.2362571009817749
# Residence - p-value: 0.07575046814372506
# School Type - p-value: 0.18940847178854656
# Hooks - p-value: 0.02074327984257632
# Major - p-value: 0.5912433288229946
# Gender - p-value: 0.3161865360675264
# Race - p-value: 0.175244802919885
# Residence - p-value: 0.1412438154655735
# School Type - p-value: 0.28725058551419175
# Hooks - p-value: 0.21269387876224108
# Major - p-value: 0.9676519379205017
# Gender - p-value: 0.7643337267263675
# Race - p-value: 0.018247506063465965
# Residence - p-value: 0.6782727670337418
# School Type - p-value: 0.14087563267398837
# Hooks - p-value: 0.05520457890269509
# Major - p-value: 0.08222414827236758
# Gender - p-value: 0.22733584043559954
# Race - p-value: 3.8133095147634786e-06
# Residence - p-value: 0.8710401964653499
# School Type - p-value: 0.9879794297744712
# Hooks - p-value: 0.000289551471247682
# Major - p-value: 0.5583682269097164
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# Gender - p-value: 0.3659323590071686
# Race - p-value: 0.2433363078892747
# Residence - p-value: 0.5546351185246339
# School Type - p-value: 0.23216382275028927
# Hooks - p-value: 0.801304184036346
# Major - p-value: 0.31912122018515837
# Gender - p-value: 0.000849948750527112
# Race - p-value: 0.013688675471588729
# Residence - p-value: 0.41942718038362914
# School Type - p-value: 0.5016952681998704
# Hooks - p-value: 0.00010788349169325996
# Major - p-value: 0.034923169992693216
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# Gender - p-value: 0.512672293337369
# Race - p-value: 0.7819618718501553
# Residence - p-value: 0.32061747448490474
# School Type - p-value: 0.9481204895306119
# Hooks - p-value: 0.00027779131619236396
# Major - p-value: 0.726456274246492
# Gender - p-value: 0.38550066593480803
# Race - p-value: 0.134621060055381
# Residence - p-value: 0.5164732843018904
# School Type - p-value: 0.5105320664753038
# Hooks - p-value: 0.11196423232087041
# Major - p-value: 0.6464760692681109
# Gender - p-value: 0.5177989438125821
# Race - p-value: 0.0037058799775215503
# Residence - p-value: 0.14265289923601218
# School Type - p-value: 0.3820194867152279
# Hooks - p-value: 0.01875461478842874
# Major - p-value: 0.41201625699172045
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# Gender - p-value: 0.8552949289024405
# Race - p-value: 0.12551188920049783
# Residence - p-value: 0.1935573608198861
# School Type - p-value: 0.8600665342880951
# Hooks - p-value: 0.10463581172802706
# Major - p-value: 0.2308938271150966
# Gender - p-value: 0.7433565946586942
# Race - p-value: 0.010020580337750152
# Residence - p-value: 0.7603688696718137
# School Type - p-value: 0.701123290852987
# Hooks - p-value: 0.0950403766116608
# Major - p-value: 0.07727372284125077
# Gender - p-value: 0.005267443716333508
# Race - p-value: 0.08655180052291762
# Residence - p-value: 0.710223649390302
# School Type - p-value: 0.2060307004048253
# Hooks - p-value: 0.024507332106505506
# Major - p-value: 0.023876328825588027
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:28: SettingWithCopyWarning:
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# Gender - p-value: 0.8518110949285609
# Race - p-value: 0.228236526024426
# Residence - p-value: 0.009845770262415062
# School Type - p-value: 0.48281461259649006
# Hooks - p-value: 0.46209932132791387
# Major - p-value: 0.2965389013492065
# Gender - p-value: 0.5967366030500114
# Race - p-value: 0.0314713211901781
# Residence - p-value: 0.13653503346260387
# School Type - p-value: 0.011655776752070834
# Hooks - p-value: 0.5876673815007023
# Major - p-value: 0.2263209803976586
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# Gender - p-value: 0.2735409782701583
# Race - p-value: 0.028286368762763105
# Residence - p-value: 0.4180359362280223
# School Type - p-value: 0.8526241226365905
# Hooks - p-value: 0.4768399018028423
# Major - p-value: 0.16064044857113557
# Gender - p-value: 0.9766179316901531
# Race - p-value: 0.9341530199071562
# Residence - p-value: 0.6208219436152532
# School Type - p-value: 0.6369005301883999
# Hooks - p-value: 0.8544996627688826
# Major - p-value: 0.8910640256791766
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# Gender - p-value: 0.5828256932205562
# Race - p-value: 0.861346547429588
# Residence - p-value: 5.072417612555558e-06
# School Type - p-value: 0.018414199821786013
# Hooks - p-value: 0.9794959188201996
# Major - p-value: 0.0071488400459272985
# Gender - p-value: 0.8105201782490551
# Race - p-value: 0.49755211124668663
# Residence - p-value: 0.29372137758691
# School Type - p-value: 0.41513388880760904
# Hooks - p-value: 0.5249467904497893
# Major - p-value: 0.7271286153187517
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_34564\3957101406.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# Gender - p-value: 0.2564469820663367
# Race - p-value: 0.7230274733853895
# Residence - p-value: 0.1875103211556064
# School Type - p-value: 0.9925510495147312
# Hooks - p-value: 0.2732140058239931
# Major - p-value: 0.2698080715369154

# %%
overall_df
# Out:
#                        School Applications Acceptances Waitlists Rejections  \
# 0                        UCLA          530         136       139        255
# 1                     HARVARD          506          67        77        362
# 2                        YALE          489          87        34        368
# 3                    STANFORD          534          69        22        443
# 4                NORTHWESTERN          417          89        56        272
# 5                    COLUMBIA          519         112        93        314
# 6                     CORNELL          585         153       105        327
# 7                    BERKELEY          473         143        60        270
# 8                        DUKE          396         100        49        247
# 9                   PRINCETON          424          77        42        305
# 10                       UCSD          280         147        68         65
# 11                        MIT          347         100        24        223
# 12                    CALTECH          166          28         9        129
# 13               GEORGIA TECH          317         129        58        130
# 14              JOHNS HOPKINS          208          54        36        118
# 15                 SWARTHMORE          135          29        31         75
# 16                  DARTMOUTH          257          52        49        156
# 17                        CMU          340          85       122        133
# 18                     PURDUE          270         184        24         62
# 19                       RICE          252          72        65        115
# 20                     POMONA          130          51        26         53
# 21                   WILLIAMS          145          45        36         64
# 22                 VANDERBILT          274          61        81        132
# 23                        NYU          326          98        58        170
# 24                      UPENN          618         218        72        328
# 25                      UMICH          451         171       137        143
# 26                      EMORY          196          66        52         78
# 27               CASE WESTERN          165          93        35         37
# 28                        USC          301         128         7        166
# 29                       UCSB          187         101        25         61
# 30                        UCD          200         122        46         32
# 31                       UCSC          113          84        16         13
# 32                        UCR           69          59         3          7
# 33                       UIUC          301         160        29        112
# 34          BOSTON UNIVERSITY          190          72        52         66
# 35             BOSTON COLLEGE          106          39        36         31
# 36                      WASHU          206          55        46        105
# 37                  UT-AUSTIN          172          74         4         94
# 38                  UT-DALLAS           30          28         0          2
# 39                    FORDHAM          121          96         7         18
# 40                    RUTGERS           84          78         1          5
# 41  San Jose State University           56          45         0         11
# 42              VIRGINIA TECH           76          44        17         15
# 43               NORTHEASTERN          434         167       113        154
# 44                    COLGATE           50          18         9         23
# 45                 UW MADISON           76          54         6         16
# 46                      TUFTS          191          48        26        117
# 47                     TULANE           68          17        24         27
# 48                HARVEY MUDD           56          13        13         30
# 49                   UCHICAGO          226          38        77        111
# 50            UNC CHAPEL HILL          101          56        11         34
# 51                        UVA          285         136        57         92
# 52          CLAREMONT MCKENNA           32           6         9         17
# 53              ARIZONA STATE          112          99         1         12
# 54                       TAMU           61          55         1          5
# 55                        UCI          295         126        85         84
# 56                        UCM           23          20         1          2
#
#     AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg  AcceptedECAvg  \
# 0      1497.794118       1516.978417     1489.058824       6.253676
# 1      1520.298507       1538.181818     1517.872928       7.037313
# 2      1514.482759       1535.882353     1514.646739       6.833333
# 3      1526.521739       1500.454545     1520.067720       6.681159
# 4      1513.033708       1538.928571     1510.919118       6.426966
# 5      1515.625000       1525.053763     1503.089172       6.683036
# 6      1509.803922       1533.904762     1502.385321       6.227451
# 7      1496.853147       1511.833333     1502.111111       6.410490
# 8      1524.800000       1532.040816     1508.785425       6.870000
# 9      1522.207792       1528.571429     1519.475410       7.038961
# 10     1490.340136       1493.088235     1492.307692       5.989796
# 11     1510.400000       1528.750000     1525.156951       6.175000
# 12     1534.285714       1520.000000     1525.658915       6.517857
# 13     1532.868217       1522.758621     1501.076923       6.541085
# 14     1493.333333       1521.388889     1498.644068       6.101852
# 15     1512.413793       1510.322581     1511.200000       6.086207
# 16     1517.307692       1528.775510     1497.371795       6.730769
# 17     1516.470588       1531.393443     1500.601504       6.517647
# 18     1507.989130       1508.750000     1484.516129       6.273370
# 19     1521.527778       1511.846154     1505.478261       6.493056
# 20     1460.588235       1474.230769     1498.113208       5.549020
# 21     1519.333333       1490.555556     1500.000000       6.722222
# 22     1519.508197       1537.160494     1503.787879       6.573770
# 23     1517.346939       1516.034483     1460.411765       6.280612
# 24     1490.779817       1532.222222     1506.768293       6.165138
# 25     1513.567251       1520.729927     1484.195804       6.232749
# 26     1499.545455       1510.000000     1485.128205       5.916667
# 27     1508.387097       1505.714286     1498.918919       5.833333
# 28     1502.031250       1532.857143     1489.759036       6.101562
# 29     1491.287129       1516.000000     1482.295082       6.039604
# 30     1487.868852       1503.913043     1473.125000       5.831967
# 31     1498.571429       1471.875000     1433.076923       6.160714
# 32     1474.576271       1556.666667     1465.714286       5.923729
# 33     1518.750000       1521.379310     1510.535714       6.304375
# 34     1495.416667       1484.423077     1464.848485       5.902778
# 35     1506.410256       1466.666667     1467.419355       5.884615
# 36     1515.454545       1525.000000     1508.857143       6.609091
# 37     1495.270270       1512.500000     1494.255319       6.067568
# 38     1510.357143               NaN     1385.000000       6.482143
# 39     1465.833333       1398.571429     1466.666667       5.651042
# 40     1486.666667       1450.000000     1518.000000       5.692308
# 41     1519.333333               NaN     1440.909091       6.100000
# 42     1468.409091       1447.058824     1444.666667       5.693182
# 43     1503.532934       1499.734513     1472.987013       5.772455
# 44     1483.888889       1466.666667     1487.391304       4.944444
# 45     1517.962963       1503.333333     1443.750000       5.912963
# 46     1498.125000       1521.153846     1495.897436       6.145833
# 47     1452.352941       1508.333333     1425.185185       6.500000
# 48     1502.307692       1558.461538     1529.333333       6.730769
# 49     1498.421053       1535.584416     1504.054054       6.578947
# 50     1516.785714       1464.545455     1480.000000       6.437500
# 51     1483.970588       1491.929825     1481.086957       5.801471
# 52     1436.666667       1495.555556     1479.411765       5.583333
# 53     1482.020202       1250.000000     1505.833333       5.348485
# 54     1505.090909       1510.000000     1480.000000       5.958182
# 55     1502.857143       1513.058824     1465.595238       6.115079
# 56     1520.500000       1580.000000     1195.000000       6.050000
#
#     WaitlistedECAvg  ...  RejectedEssayAvg  COR-SAT-EC  COR-SAT-ESSAY  \
# 0          6.253957  ...          4.885490    0.364646       0.078477
# 1          6.597403  ...          5.334807    0.196356       0.089163
# 2          6.823529  ...          5.454891    0.208734       0.128943
# 3          7.045455  ...          5.207901    0.266427       0.071241
# 4          6.187500  ...          5.381250    0.154918       0.028023
# 5          6.675269  ...          5.523885    0.284199        0.03337
# 6          6.616190  ...          5.333639    0.214273       0.010087
# 7          6.308333  ...          5.029259    0.353828       0.041427
# 8          6.622449  ...          5.348178    0.247399       0.047991
# 9          7.000000  ...          5.412131    0.251275        0.03719
# 10         5.732353  ...          5.113846     0.33068       0.004146
# 11         6.833333  ...          5.299776    0.248841       0.132642
# 12         7.333333  ...          5.235271    0.289057      -0.051728
# 13         6.184483  ...          4.977692    0.276164      -0.013391
# 14         6.027778  ...          5.117797    0.279297      -0.020587
# 15         5.967742  ...          5.630667    0.064612       0.245387
# 16         6.683673  ...          5.556410    0.311752       0.010289
# 17         6.497541  ...          5.024812    0.224479      -0.028426
# 18         6.508333  ...          4.850000    0.230769      -0.060848
# 19         6.249231  ...          5.451304    0.338514       0.131598
# 20         5.711538  ...          5.128302    0.306212       0.229854
# 21         5.763889  ...          5.210938    0.213561       0.038943
# 22         6.191358  ...          5.494697    0.151013       0.011676
# 23         6.439655  ...          5.198529     0.26368        0.07972
# 24         6.847222  ...          5.243293     0.29967       0.038778
# 25         6.235036  ...          4.933566    0.223591      -0.027483
# 26         6.057692  ...          5.293590    0.217189       0.186423
# 27         5.128571  ...          4.429730    0.131876       0.075491
# 28         5.642857  ...          4.951205    0.337595       0.065248
# 29         6.200000  ...          5.113115    0.317051       0.056074
# 30         5.652174  ...          5.065625    0.359325      -0.128064
# 31         4.781250  ...          4.038462     0.21167       0.090918
# 32         5.333333  ...          5.314286    0.420185       0.045004
# 33         5.975862  ...          4.671429    0.257655      -0.107113
# 34         5.807692  ...          5.328788    0.254032       0.109587
# 35         5.638889  ...          5.003226    0.258074       0.196932
# 36         6.206522  ...          5.014286    0.245376       -0.01318
# 37         7.000000  ...          5.409574    0.299645       0.037429
# 38              NaN  ...          3.850000    0.140418       0.117615
# 39         6.357143  ...          4.711111    0.281452       0.024831
# 40         1.000000  ...          4.580000    0.269346        0.03926
# 41              NaN  ...          5.490909    0.348817       0.020658
# 42         5.088235  ...          4.753333    0.207112        0.00023
# 43         6.128319  ...          5.175974    0.165862       0.089985
# 44         5.166667  ...          5.395652    0.108622      -0.257148
# 45         5.250000  ...          5.443750    0.049555      -0.237273
# 46         5.557692  ...          5.329915    0.034095       0.052532
# 47         5.520833  ...          4.803704    0.239678       0.039789
# 48         6.230769  ...          4.543333   -0.121382       0.008099
# 49         6.240260  ...          5.568468    0.268404       0.108723
# 50         5.954545  ...          5.370588    0.182044       0.034837
# 51         5.561404  ...          4.815217    0.284343      -0.001789
# 52         4.944444  ...          4.958824    0.150568      -0.027074
# 53         1.000000  ...          5.275000    0.209317       -0.04406
# 54         6.500000  ...          3.760000    0.179346      -0.020328
# 55         5.970588  ...          5.029762    0.353865       0.100596
# 56         6.500000  ...          5.350000    0.441398      -0.021479
#
#     COR-EC-ESSAY              pval-Gender                 pval-Race  \
# 0       0.166158    {0.17347857919743745}      {0.7186090880560159}
# 1       0.068669     {0.5381453938691496}     {0.05055003905776786}
# 2       0.076969  {0.0034708386085071344}     {0.15507107919903979}
# 3       0.038232   {0.008791793880671736}      {0.2644214871220135}
# 4       0.153525     {0.7437779455117788}  {1.9585648286494958e-05}
# 5       0.054902    {0.37021041566748714}     {0.10157324701113779}
# 6       0.089095     {0.4432628106323325}      {0.2362571009817749}
# 7        0.14031     {0.3161865360675264}       {0.175244802919885}
# 8       0.093827     {0.7643337267263675}    {0.018247506063465965}
# 9       0.043916    {0.22733584043559954}  {3.8133095147634786e-06}
# 10      0.148849     {0.3659323590071686}      {0.2433363078892747}
# 11      0.121864   {0.000849948750527112}    {0.013688675471588729}
# 12      0.033052      {0.512672293337369}      {0.7819618718501553}
# 13      0.071957    {0.38550066593480803}       {0.134621060055381}
# 14      0.036201     {0.5177989438125821}   {0.0037058799775215503}
# 15      0.052421     {0.8552949289024405}     {0.12551188920049783}
# 16      0.092985     {0.7433565946586942}    {0.010020580337750152}
# 17      0.141945   {0.005267443716333508}     {0.08655180052291762}
# 18      0.204773    {0.06443423173922913}      {0.5631073693431816}
# 19      0.155226    {0.28681005121418746}       {0.602974582875021}
# 20      0.158067     {0.2339012121916239}     {0.10986248014715969}
# 21      0.096891     {0.5865521022916388}      {0.3985954079784134}
# 22      0.130539     {0.8073267411617788}    {0.026612112768505104}
# 23         0.175    {0.49091113464950376}     {0.06065169544516163}
# 24       0.13662     {0.1604043862608993}     {0.15812533353247776}
# 25      0.126905   {0.016847911549311485}       {0.482518680276005}
# 26      0.208236    {0.06400308877895894}     {0.06279085887055401}
# 27       0.00759     {0.1004346384496467}      {0.5010380419644394}
# 28      0.212596     {0.9715019790384444}      {0.7796383267315001}
# 29      0.167294  {0.0018414448461657636}      {0.4457894139849431}
# 30      0.206271    {0.30474241123884327}     {0.19227253821355916}
# 31      0.325196     {0.3220332765213141}      {0.8121730563996542}
# 32      0.256665    {0.05952478129940644}      {0.9357995861969367}
# 33      0.162302   {0.021323002222353893}      {0.7878045212894728}
# 34      0.158654     {0.7502201509843633}    {0.009455988695321936}
# 35      0.032557    {0.14631673647322024}      {0.8427521822221311}
# 36       0.10622     {0.7022166378157051}    {0.014290221341825244}
# 37      0.070128  {0.0006619162063871339}     {0.46322159855234435}
# 38      0.508406     {0.7230404812628726}     {0.14716383467707222}
# 39      0.244701    {0.44750811094440446}      {0.6608340603961655}
# 40      0.179458     {0.9301134717176817}    {0.005496654850360291}
# 41      0.113885   {0.021468142536880702}     {0.46918523359704467}
# 42     -0.017798     {0.8236627111541064}    {0.035371003367184586}
# 43      0.093418     {0.6700221244139484}      {0.7278566975993448}
# 44       0.07818     {0.6541026455393184}      {0.8666560180231921}
# 45      0.165938     {0.5552593843207867}      {0.6326081622710324}
# 46      0.086407     {0.6757363211789468}     {0.08994010949193837}
# 47      0.063745     {0.4531489536538207}     {0.45838962835623354}
# 48      0.249004    {0.20762323752155076}     {0.03986041886023408}
# 49      0.162892    {0.38782354714934414}     {0.08119722236822591}
# 50      0.086517     {0.8518110949285609}       {0.228236526024426}
# 51     -0.028024     {0.5967366030500114}      {0.0314713211901781}
# 52      0.164606     {0.2735409782701583}    {0.028286368762763105}
# 53      0.273382     {0.9766179316901531}      {0.9341530199071562}
# 54      0.229618     {0.5828256932205562}       {0.861346547429588}
# 55      0.193821     {0.8105201782490551}     {0.49755211124668663}
# 56     -0.032149     {0.2564469820663367}      {0.7230274733853895}
#
#               pval-Residence         pval-School Type  \
# 0       {0.4712126148526475}    {0.33903650126502116}
# 1     {0.011441967162762726}     {0.8912675965555017}
# 2       {0.9981974135424317}     {0.3447113188617562}
# 3       {0.6539058331344072}     {0.9834656421660932}
# 4      {0.07110811431944784}    {0.26198456948174825}
# 5       {0.7888897908577736}    {0.36071421969731476}
# 6      {0.07575046814372506}    {0.18940847178854656}
# 7       {0.1412438154655735}    {0.28725058551419175}
# 8       {0.6782727670337418}    {0.14087563267398837}
# 9       {0.8710401964653499}     {0.9879794297744712}
# 10      {0.5546351185246339}    {0.23216382275028927}
# 11     {0.41942718038362914}     {0.5016952681998704}
# 12     {0.32061747448490474}     {0.9481204895306119}
# 13      {0.5164732843018904}     {0.5105320664753038}
# 14     {0.14265289923601218}     {0.3820194867152279}
# 15      {0.1935573608198861}     {0.8600665342880951}
# 16      {0.7603688696718137}      {0.701123290852987}
# 17       {0.710223649390302}     {0.2060307004048253}
# 18     {0.15434528684715923}     {0.8596717041432773}
# 19       {0.266821958316695}    {0.14700453262822288}
# 20     {0.06728561765664257}    {0.12684451026491564}
# 21     {0.30040249249560674}     {0.4054673520059104}
# 22     {0.24486530664539669}    {0.39245455714283567}
# 23     {0.07203292122576657}     {0.8511504077059051}
# 24      {0.5609718922491655}    {0.08789606137546588}
# 25     {0.35497185992638014}    {0.46293103199819285}
# 26      {0.7640215773146598}    {0.03802606688149981}
# 27      {0.6269779262749579}     {0.7491159123719423}
# 28     {0.23355203385365214}     {0.7141202485428595}
# 29      {0.5883744145043452}    {0.26788706565999576}
# 30     {0.13729471142720878}    {0.34040221701008616}
# 31     {0.11345953540650294}     {0.6281185301280864}
# 32       {0.274908706207653}     {0.9657035630942922}
# 33    {0.009604904089708027}     {0.8701694424804716}
# 34      {0.3593536378386889}   {0.050935702302290574}
# 35       {0.177520455547426}     {0.5149506761802831}
# 36      {0.3313448922121009}     {0.2844286366747223}
# 37  {0.00040478762754243836}  {0.0016292897002506358}
# 38      {0.8120281163712236}     {0.7832049228270577}
# 39  {0.00026963455642859725}     {0.9008714852923833}
# 40    {7.32341558003077e-09}    {0.15486660642961778}
# 41      {0.7902701241127743}     {0.5783999856060904}
# 42     {0.21195863496828407}     {0.0800087166238275}
# 43      {0.4607204172464878}     {0.6257896189597105}
# 44    {0.039804944120201004}   {0.009714939594649991}
# 45     {0.10603573645408548}     {0.8475752890686223}
# 46      {0.5459696113299108}     {0.9156675391145735}
# 47       {0.416243091230361}    {0.14185594476523802}
# 48     {0.09509824444222863}     {0.7887721997064358}
# 49       {0.658523881983436}      {0.825376469736062}
# 50    {0.009845770262415062}    {0.48281461259649006}
# 51     {0.13653503346260387}   {0.011655776752070834}
# 52      {0.4180359362280223}     {0.8526241226365905}
# 53      {0.6208219436152532}     {0.6369005301883999}
# 54   {5.072417612555558e-06}   {0.018414199821786013}
# 55        {0.29372137758691}    {0.41513388880760904}
# 56      {0.1875103211556064}     {0.9925510495147312}
#
#                   pval-Hooks               pval-Major
# 0       {0.4213690400108201}    {0.11917239950270872}
# 1     {0.015057192373553827}     {0.6264421115451353}
# 2     {0.004352900644245513}     {0.9918697792801817}
# 3     {0.023060097662893176}     {0.5990256483325999}
# 4   {0.00015184857523332105}   {0.030056908411837287}
# 5     {0.031193940017445118}     {0.5123200494329931}
# 6      {0.02074327984257632}     {0.5912433288229946}
# 7      {0.21269387876224108}     {0.9676519379205017}
# 8      {0.05520457890269509}    {0.08222414827236758}
# 9     {0.000289551471247682}     {0.5583682269097164}
# 10       {0.801304184036346}    {0.31912122018515837}
# 11  {0.00010788349169325996}   {0.034923169992693216}
# 12  {0.00027779131619236396}      {0.726456274246492}
# 13     {0.11196423232087041}     {0.6464760692681109}
# 14     {0.01875461478842874}    {0.41201625699172045}
# 15     {0.10463581172802706}     {0.2308938271150966}
# 16      {0.0950403766116608}    {0.07727372284125077}
# 17    {0.024507332106505506}   {0.023876328825588027}
# 18     {0.05654187532973343}     {0.5745032196104803}
# 19     {0.17850194104163972}    {0.19428662572456834}
# 20      {0.4182026450269101}     {0.9377710270464708}
# 21      {0.7113955453093767}    {0.14448618924184442}
# 22     {0.26749311742156173}     {0.5096401973900604}
# 23      {0.6816604805871469}     {0.3881214185831508}
# 24      {0.7170695067526818}   {0.053574808097364764}
# 25    {0.002952723959280514}     {0.5962775161492992}
# 26     {0.05114973417535227}     {0.7672351402258968}
# 27     {0.39851212185922963}     {0.9842880090050877}
# 28        {0.74804378648738}     {0.8221331770919345}
# 29     {0.30994219462043254}     {0.3652370421502042}
# 30     {0.35534622565276386}      {0.316226487617536}
# 31     {0.14850362573444784}     {0.6412960985516896}
# 32      {0.9479790348299789}     {0.9995808312723571}
# 33     {0.12035476504591582}     {0.9670524418858202}
# 34      {0.2868996098993753}    {0.06695367766405637}
# 35     {0.10944714929639139}   {0.028684452547034927}
# 36      {0.6976917869337693}    {0.40958891186072677}
# 37    {0.007090798042559361}   {0.000828873461842133}
# 38     {0.16255395823358015}     {0.0616432733373023}
# 39      {0.9344720905458512}     {0.9996983118044739}
# 40      {0.4695178927904311}     {0.6267823110117297}
# 41      {0.8856223995832663}     {0.8824675923183887}
# 42     {0.18384436572768983}    {0.17595548971879998}
# 43     {0.08651266467889551}     {0.6931625831342764}
# 44      {0.5650297001991441}      {0.555139634846189}
# 45     {0.39809438889850374}     {0.4638502389300476}
# 46     {0.20711062848510028}     {0.6830398921974707}
# 47      {0.5940285499866158}     {0.6088725778002402}
# 48     {0.33924554032839416}    {0.13279509257504765}
# 49     {0.04818973905698501}     {0.7696984247020983}
# 50     {0.46209932132791387}     {0.2965389013492065}
# 51      {0.5876673815007023}     {0.2263209803976586}
# 52      {0.4768399018028423}    {0.16064044857113557}
# 53      {0.8544996627688826}     {0.8910640256791766}
# 54      {0.9794959188201996}  {0.0071488400459272985}
# 55      {0.5249467904497893}     {0.7271286153187517}
# 56      {0.2732140058239931}     {0.2698080715369154}
#
# [57 rows x 23 columns]
