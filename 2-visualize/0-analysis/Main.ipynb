# %%
import pandas as pd

df = pd.read_csv('CLEAN.csv')
df = df.drop(columns=['Note'])
df
# Out:
#      Gender   Race Residence  Income School Type Hooks         Major   SAT  \
# 0         M  ASIAN        MI     Low          -1  NONE            CS  1440
# 1     OTHER  ASIAN        IN    High          -1  NONE            CS  1390
# 2         F  ASIAN        MA    High      PUBLIC  NONE  NEUROSCIENCE  1580
# 3         M  WHITE        IN     Low          -1   URM            CS  1580
# 4         F  ASIAN        OR  Middle      PUBLIC  NONE            CS  1580
# ...     ...    ...       ...     ...         ...   ...           ...   ...
# 1479      M  ASIAN        GA  Middle      PUBLIC  LGBT           BIO  1580
# 1480      F  ASIAN        CA    High      PUBLIC  NONE            CS  1590
# 1481      M  ASIAN        CA  Middle      PUBLIC  NONE           ENG  1240
# 1482      M  ASIAN        CA     Low      PUBLIC  NONE            CS  1580
# 1483      M  ASIAN        FL    High      PUBLIC  NONE            CS  1560
#
#       EC-AWARDS  ESSAY-LOR-INTERVIEW  \
# 0           2.0                  4.5
# 1           5.5                  4.5
# 2           7.5                  7.5
# 3           5.5                  1.5
# 4           7.5                  4.7
# ...         ...                  ...
# 1479        5.0                  3.5
# 1480        7.5                  3.5
# 1481        3.0                  6.5
# 1482        6.5                  7.5
# 1483        8.5                  8.5
#
#                                             Acceptances  \
# 0                                           ['*PURDUE']
# 1                                         ['*STANFORD']
# 2     ['*UCLA', '*HARVARD', '*YALE', '*COLUMBIA', '*...
# 3     ['*GEORGIA TECH', '*UT-AUSTIN', '*ARIZONA STAT...
# 4                              ['*CORNELL', '*RUTGERS']
# ...                                                 ...
# 1479                         ['*NYU', '*UMICH', '*USC']
# 1480       ['*DUKE', '*UCSD', '*UIUC', '*NORTHEASTERN']
# 1481                                           ['*UCI']
# 1482  ['*UCLA', '*PURDUE', '*POMONA', '*ARIZONA STAT...
# 1483  ['*UCLA', '*UCSD', '*GEORGIA TECH', '*PURDUE',...
#
#                                               Waitlists  \
# 0                           ['*GEORGIA TECH', '*UMICH']
# 1                                                    []
# 2                                            ['*UPENN']
# 3                             ['*HARVARD', '*UCHICAGO']
# 4                                                    []
# ...                                                 ...
# 1479                    ['*JOHNS HOPKINS', '*UCHICAGO']
# 1480                          ['*CMU', '*UCSB', '*UCI']
# 1481                                        ['*POMONA']
# 1482  ['*UCLA', '*STANFORD', '*CORNELL', '*GEORGIA T...
# 1483  ['*COLUMBIA', '*CORNELL', '*BERKELEY', '*PRINC...
#
#                                              Rejections
# 0                            ['*UIUC', '*NORTHEASTERN']
# 1                                          ['*CALTECH']
# 2                            ['*STANFORD', '*COLUMBIA']
# 3     ['*UCLA', '*NORTHWESTERN', '*UMICH', '*EMORY',...
# 4                                          ['*CORNELL']
# ...                                                 ...
# 1479  ['*HARVARD', '*YALE', '*BROWN', '*STANFORD', '...
# 1480  ['*UCLA', '*HARVARD', '*BROWN', '*STANFORD', '...
# 1481                             ['*UCLA', '*BERKELEY']
# 1482  ['*HARVARD', '*YALE', '*COLUMBIA', '*MIT', '*C...
# 1483      ['*HARVARD', '*STANFORD', '*MIT', '*CALTECH']
#
# [1484 rows x 13 columns]

# %%
colleges = [ '*UCLA', '*HARVARD', '*YALE'
, '*STANFORD', '*NORTHWESTERN', '*COLUMBIA', '*CORNELL', '*BERKELEY'
, '*DUKE', '*PRINCETON', '*UCSD', '*MIT', '*CALTECH', '*GEORGIA TECH'
, '*JOHNS HOPKINS', '*SWARTHMORE', '*DARTMOUTH', '*CMU', '*PURDUE'
, '*RICE', '*POMONA', '*WILLIAMS', '*VANDERBILT', '*NYU', '*UPENN'
, '*UMICH', '*EMORY', '*CASE WESTERN', '*USC', '*UCSB', '*UCD', '*UCSC'
, '*UCR', '*UIUC', '*BOSTON UNIVERSITY', '*BOSTON COLLEGE', '*WASHU'
, '*UT-AUSTIN', '*UT-DALLAS', '*FORDHAM', '*RUTGERS', '*San Jose State University'
, '*VIRGINIA TECH', '*NORTHEASTERN', '*UW SEATTLE', '*COLGATE', '*UW MADISON'
, '*TUFTS', '*TULANE', '*HARVEY MUDD', '*UCHICAGO', '*UNC CHAPEL HILL'
, '*UVA', '*CLAREMONT MCKENNA', '*ARIZONA STATE', '*TAMU', '*UCI', '*UCM']
# *BROWN
# *STANFORD
# *NORTHWESTERN
# *COLUMBIA
# *CORNELL
# *BERKELEY
# *DUKE
# *PRINCETON
# *UCSD
# *MIT
# *CALTECH
# *GEORGIA TECH
# *JOHNS HOPKINS
# *SWARTHMORE
# *DARTMOUTH
# *CMU
# *PURDUE
# *RICE
# *POMONA
# *WILLIAMS
# *VANDERBILT
# *NYU
# *UPENN
# *UMICH
# *EMORY
# *CASE WESTERN
# *USC
# *UCSB
# *UCD
# *UCSC
# *UCR
# *UIUC
# *BOSTON UNIVERSITY
# *BOSTON COLLEGE
# *WASHU
# *UT-AUSTIN
# *UT-DALLAS
# *FORDHAM
# *RUTGERS
# *San Jose State University
# *VIRGINIA TECH
# *NORTHEASTERN
# *UW SEATTLE
# *COLGATE
# *UW MADISON
# *TUFTS
# *TULANE
# *HARVEY MUDD
# *UCHICAGO
# *UNC CHAPEL HILL
# *UVA
# *CLAREMONT MCKENNA
# *ARIZONA STATE
# *TAMU
# *UCI
# *UCM

# %%
def basicAnalysis(df, college):
    
    ret = []
    ret.append(college)
    ret.append(len(df))

    accepted = df[df['Decision'] == 0]
    waitlist = df[df['Decision'] == 1]
    rejected = df[df['Decision'] == 2]

    return [college, len(df), len(accepted), len(waitlist), len(rejected), accepted['SAT'].mean(), waitlisted['SAT'].mean(), rejected['SAT'].mean(), accepted['EC-AWARDS'].mean(), waitlist['EC-AWARDS'].mean(), rejected['EC-AWARDS'].mean(), accepted['ESSAY-LOR-INTERVIEW'].mean(), waitlist['ESSAY-LOR-INTERVIEW'].mean(), rejected['ESSAY-LOR-INTERVIEW'].mean(), 0, 0, 0]
    #return ['School', 'Applications', 'Acceptances', 'Waitlists', 'Rejections', 'AcceptedSATAvg', 'WaitlistedSATAvg', 'RejectedSATAvg', 'AcceptedECAvg', 'WaitlistedECAvg', 'RejectedECAvg', 'AcceptedEssayAvg', 'WaitlistedEssayAvg', 'RejectedEssayAvg']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def getNumericalCorrelations(df, college, overall_df):
    # Correlation matrix for NUMBER rows
    corr_matrix = df[['SAT', 'EC-AWARDS', 'ESSAY-LOR-INTERVIEW']].corr()
    sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
    plt.title(str(college) + " Correlation Matrix")
    plt.savefig(f"res/{college}/"+str(college) + " Correlation Matrix.png")
    plt.close()

    
    #add the correlation matrix to the overalldf
    mask = overall_df['School'] == college
    if mask.sum() == 1:
        overall_df.loc[mask, 'COR-SAT-EC'] = corr_matrix['SAT']['EC-AWARDS']
        overall_df.loc[mask, 'COR-SAT-ESSAY'] = corr_matrix['SAT']['ESSAY-LOR-INTERVIEW']
        overall_df.loc[mask, 'COR-EC-ESSAY'] = corr_matrix['EC-AWARDS']['ESSAY-LOR-INTERVIEW']
        print(overall_df[mask])
    else:
        print(f"Error: Found {mask.sum()} rows for {college}")

    return overall_df

# %%
overall_df = pd.DataFrame(columns=['School', 'Applications', 'Acceptances', 'Waitlists', 'Rejections', 
                                   'AcceptedSATAvg', 'WaitlistedSATAvg', 'RejectedSATAvg', 
                                   'AcceptedECAvg', 'WaitlistedECAvg', 'RejectedECAvg', 
                                   'AcceptedEssayAvg', 'WaitlistedEssayAvg', 'RejectedEssayAvg',
                                   
                                   #correlations
                                    'COR-SAT-EC', 'COR-SAT-ESSAY', 'COR-EC-ESSAY'
                                   ])

for college in colleges:
    college = college.removeprefix('*')
    
    accepted = df[df['Acceptances'].str.contains(college, regex=False)]
    accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
    accepted['Decision'] = 0

    rejected = df[df['Rejections'].str.contains(college, regex=False)]
    rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
    rejected['Decision'] = 2
    
    waitlisted = df[df['Waitlists'].str.contains(college, regex=False)]
    waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
    waitlisted['Decision'] = 1

    college_df = pd.concat([accepted, rejected, waitlisted])

    
    #create folder if it doesnt exist
    import os
    if not os.path.exists(f'res/{college}'):
        os.makedirs(f'res/{college}')


    #basic analysis
    overall_df = pd.concat([overall_df, pd.DataFrame([basicAnalysis(college_df, college)], columns=overall_df.columns)], ignore_index=True)

    #correlations between features
    overall_df = getNumericalCorrelations(college_df, college, overall_df)

    
    # save the dataset
    college_df.to_csv(f'res/{college}/dataset.csv', index=False)
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:35: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   overall_df = pd.concat([overall_df, pd.DataFrame([basicAnalysis(college_df, college)], columns=overall_df.columns)], ignore_index=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
#   School Applications Acceptances Waitlists Rejections  AcceptedSATAvg  \
# 0   UCLA          530         136       139        255     1497.794118
#
#    WaitlistedSATAvg  RejectedSATAvg  AcceptedECAvg  WaitlistedECAvg  \
# 0       1516.978417     1489.058824       6.253676         6.253957
#
#    RejectedECAvg  AcceptedEssayAvg  WaitlistedEssayAvg  RejectedEssayAvg  \
# 0        5.85098          5.018015                 5.1           4.88549
#
#   COR-SAT-EC COR-SAT-ESSAY COR-EC-ESSAY
# 0   0.364646      0.078477     0.166158
#     School Applications Acceptances Waitlists Rejections  AcceptedSATAvg  \
# 1  HARVARD          506          67        77        362     1520.298507
#
#    WaitlistedSATAvg  RejectedSATAvg  AcceptedECAvg  WaitlistedECAvg  \
# 1       1538.181818     1517.872928       7.037313         6.597403
#
#    RejectedECAvg  AcceptedEssayAvg  WaitlistedEssayAvg  RejectedEssayAvg  \
# 1        6.28232          5.708955             5.61039          5.334807
#
#   COR-SAT-EC COR-SAT-ESSAY COR-EC-ESSAY
# 1   0.196356      0.089163     0.068669
#   School Applications Acceptances Waitlists Rejections  AcceptedSATAvg  \
# 2   YALE          489          87        34        368     1514.482759
#
#    WaitlistedSATAvg  RejectedSATAvg  AcceptedECAvg  WaitlistedECAvg  \
# 2       1535.882353     1514.646739       6.833333         6.823529
#
#    RejectedECAvg  AcceptedEssayAvg  WaitlistedEssayAvg  RejectedEssayAvg  \
# 2       6.213315          5.378161                 5.5          5.454891
#
#   COR-SAT-EC COR-SAT-ESSAY COR-EC-ESSAY
# 2   0.208734      0.128943     0.076969
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
#      School Applications Acceptances Waitlists Rejections  AcceptedSATAvg  \
# 3  STANFORD          534          69        22        443     1526.521739
#
#    WaitlistedSATAvg  RejectedSATAvg  AcceptedECAvg  WaitlistedECAvg  \
# 3       1500.454545      1520.06772       6.681159         7.045455
#
#    RejectedECAvg  AcceptedEssayAvg  WaitlistedEssayAvg  RejectedEssayAvg  \
# 3       6.418736          5.428986            4.690909          5.207901
#
#   COR-SAT-EC COR-SAT-ESSAY COR-EC-ESSAY
# 3   0.266427      0.071241     0.038232
#          School Applications Acceptances Waitlists Rejections  AcceptedSATAvg  \
# 4  NORTHWESTERN          417          89        56        272     1513.033708
#
#    WaitlistedSATAvg  RejectedSATAvg  AcceptedECAvg  WaitlistedECAvg  \
# 4       1538.928571     1510.919118       6.426966           6.1875
#
#    RejectedECAvg  AcceptedEssayAvg  WaitlistedEssayAvg  RejectedEssayAvg  \
# 4       6.258088          5.493258              5.2625           5.38125
#
#   COR-SAT-EC COR-SAT-ESSAY COR-EC-ESSAY
# 4   0.154918      0.028023     0.153525
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
#      School Applications Acceptances Waitlists Rejections  AcceptedSATAvg  \
# 5  COLUMBIA          519         112        93        314        1515.625
#
#    WaitlistedSATAvg  RejectedSATAvg  AcceptedECAvg  WaitlistedECAvg  \
# 5       1525.053763     1503.089172       6.683036         6.675269
#
#    RejectedECAvg  AcceptedEssayAvg  WaitlistedEssayAvg  RejectedEssayAvg  \
# 5       6.143949          5.116964            5.325806          5.523885
#
#   COR-SAT-EC COR-SAT-ESSAY COR-EC-ESSAY
# 5   0.284199       0.03337     0.054902
#     School Applications Acceptances Waitlists Rejections  AcceptedSATAvg  \
# 6  CORNELL          585         153       105        327     1509.803922
#
#    WaitlistedSATAvg  RejectedSATAvg  AcceptedECAvg  WaitlistedECAvg  \
# 6       1533.904762     1502.385321       6.227451          6.61619
#
#    RejectedECAvg  AcceptedEssayAvg  WaitlistedEssayAvg  RejectedEssayAvg  \
# 6       6.171254          5.356209            5.380952          5.333639
#
#   COR-SAT-EC COR-SAT-ESSAY COR-EC-ESSAY
# 6   0.214273      0.010087     0.089095
#      School Applications Acceptances Waitlists Rejections  AcceptedSATAvg  \
# 7  BERKELEY          473         143        60        270     1496.853147
#
#    WaitlistedSATAvg  RejectedSATAvg  AcceptedECAvg  WaitlistedECAvg  \
# 7       1511.833333     1502.111111        6.41049         6.308333
#
#    RejectedECAvg  AcceptedEssayAvg  WaitlistedEssayAvg  RejectedEssayAvg  \
# 7       6.062963          5.065035            5.301667          5.029259
#
#   COR-SAT-EC COR-SAT-ESSAY COR-EC-ESSAY
# 7   0.353828      0.041427      0.14031
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
#   School Applications Acceptances Waitlists Rejections  AcceptedSATAvg  \
# 8   DUKE          396         100        49        247          1524.8
#
#    WaitlistedSATAvg  RejectedSATAvg  AcceptedECAvg  WaitlistedECAvg  \
# 8       1532.040816     1508.785425           6.87         6.622449
#
#    RejectedECAvg  AcceptedEssayAvg  WaitlistedEssayAvg  RejectedEssayAvg  \
# 8       6.082996             5.009            4.755102          5.348178
#
#   COR-SAT-EC COR-SAT-ESSAY COR-EC-ESSAY
# 8   0.247399      0.047991     0.093827
#       School Applications Acceptances Waitlists Rejections  AcceptedSATAvg  \
# 9  PRINCETON          424          77        42        305     1522.207792
#
#    WaitlistedSATAvg  RejectedSATAvg  AcceptedECAvg  WaitlistedECAvg  \
# 9       1528.571429      1519.47541       7.038961              7.0
#
#    RejectedECAvg  AcceptedEssayAvg  WaitlistedEssayAvg  RejectedEssayAvg  \
# 9       6.327869          5.342857            5.590476          5.412131
#
#   COR-SAT-EC COR-SAT-ESSAY COR-EC-ESSAY
# 9   0.251275       0.03719     0.043916
#    School Applications Acceptances Waitlists Rejections  AcceptedSATAvg  \
# 10   UCSD          280         147        68         65     1490.340136
#
#     WaitlistedSATAvg  RejectedSATAvg  AcceptedECAvg  WaitlistedECAvg  \
# 10       1493.088235     1492.307692       5.989796         5.732353
#
#     RejectedECAvg  AcceptedEssayAvg  WaitlistedEssayAvg  RejectedEssayAvg  \
# 10       5.884615           4.99898            5.191176          5.113846
#
#    COR-SAT-EC COR-SAT-ESSAY COR-EC-ESSAY
# 10    0.33068      0.004146     0.148849
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
#    School Applications Acceptances Waitlists Rejections  AcceptedSATAvg  \
# 11    MIT          347         100        24        223          1510.4
#
#     WaitlistedSATAvg  RejectedSATAvg  AcceptedECAvg  WaitlistedECAvg  \
# 11           1528.75     1525.156951          6.175         6.833333
#
#     RejectedECAvg  AcceptedEssayAvg  WaitlistedEssayAvg  RejectedEssayAvg  \
# 11       6.348879             5.311            5.741667          5.299776
#
#    COR-SAT-EC COR-SAT-ESSAY COR-EC-ESSAY
# 11   0.248841      0.132642     0.121864
#      School Applications Acceptances Waitlists Rejections  AcceptedSATAvg  \
# 12  CALTECH          166          28         9        129     1534.285714
#
#     WaitlistedSATAvg  RejectedSATAvg  AcceptedECAvg  WaitlistedECAvg  \
# 12            1520.0     1525.658915       6.517857         7.333333
#
#     RejectedECAvg  AcceptedEssayAvg  WaitlistedEssayAvg  RejectedEssayAvg  \
# 12        6.70155          4.539286            5.466667          5.235271
#
#    COR-SAT-EC COR-SAT-ESSAY COR-EC-ESSAY
# 12   0.289057     -0.051728     0.033052
#           School Applications Acceptances Waitlists Rejections  \
# 13  GEORGIA TECH          317         129        58        130
#
#     AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg  AcceptedECAvg  \
# 13     1532.868217       1522.758621     1501.076923       6.541085
#
#     WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg  WaitlistedEssayAvg  \
# 13         6.184483       5.446154           5.17907             4.90431
#
#     RejectedEssayAvg COR-SAT-EC COR-SAT-ESSAY COR-EC-ESSAY
# 13          4.977692   0.276164     -0.013391     0.071957
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
#            School Applications Acceptances Waitlists Rejections  \
# 14  JOHNS HOPKINS          208          54        36        118
#
#     AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg  AcceptedECAvg  \
# 14     1493.333333       1521.388889     1498.644068       6.101852
#
#     WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg  WaitlistedEssayAvg  \
# 14         6.027778       6.300847           5.72037            5.388889
#
#     RejectedEssayAvg COR-SAT-EC COR-SAT-ESSAY COR-EC-ESSAY
# 14          5.117797   0.279297     -0.020587     0.036201
#         School Applications Acceptances Waitlists Rejections  AcceptedSATAvg  \
# 15  SWARTHMORE          135          29        31         75     1512.413793
#
#     WaitlistedSATAvg  RejectedSATAvg  AcceptedECAvg  WaitlistedECAvg  \
# 15       1510.322581          1511.2       6.086207         5.967742
#
#     RejectedECAvg  AcceptedEssayAvg  WaitlistedEssayAvg  RejectedEssayAvg  \
# 15       5.846667          4.710345            5.348387          5.630667
#
#    COR-SAT-EC COR-SAT-ESSAY COR-EC-ESSAY
# ...
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
#    School Applications Acceptances Waitlists Rejections  AcceptedSATAvg  \
# 52    UVA          285         136        57         92     1483.970588
#
#     WaitlistedSATAvg  RejectedSATAvg  AcceptedECAvg  WaitlistedECAvg  \
# 52       1491.929825     1481.086957       5.801471         5.561404
#
#     RejectedECAvg  AcceptedEssayAvg  WaitlistedEssayAvg  RejectedEssayAvg  \
# 52           5.75          5.523529            5.733333          4.815217
#
#    COR-SAT-EC COR-SAT-ESSAY COR-EC-ESSAY
# 52   0.284343     -0.001789    -0.028024
#                School Applications Acceptances Waitlists Rejections  \
# 53  CLAREMONT MCKENNA           32           6         9         17
#
#     AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg  AcceptedECAvg  \
# 53     1436.666667       1495.555556     1479.411765       5.583333
#
#     WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg  WaitlistedEssayAvg  \
# 53         4.944444       5.205882          4.916667            4.977778
#
#     RejectedEssayAvg COR-SAT-EC COR-SAT-ESSAY COR-EC-ESSAY
# 53          4.958824   0.150568     -0.027074     0.164606
#            School Applications Acceptances Waitlists Rejections  \
# 54  ARIZONA STATE          112          99         1         12
#
#     AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg  AcceptedECAvg  \
# 54     1482.020202            1250.0     1505.833333       5.348485
#
#     WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg  WaitlistedEssayAvg  \
# 54              1.0       5.333333          5.188889                 6.5
#
#     RejectedEssayAvg COR-SAT-EC COR-SAT-ESSAY COR-EC-ESSAY
# 54             5.275   0.209317      -0.04406     0.273382
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
#    School Applications Acceptances Waitlists Rejections  AcceptedSATAvg  \
# 55   TAMU           61          55         1          5     1505.090909
#
#     WaitlistedSATAvg  RejectedSATAvg  AcceptedECAvg  WaitlistedECAvg  \
# 55            1510.0          1480.0       5.958182              6.5
#
#     RejectedECAvg  AcceptedEssayAvg  WaitlistedEssayAvg  RejectedEssayAvg  \
# 55            6.1          5.238182                 6.2              3.76
#
#    COR-SAT-EC COR-SAT-ESSAY COR-EC-ESSAY
# 55   0.179346     -0.020328     0.229618
#    School Applications Acceptances Waitlists Rejections  AcceptedSATAvg  \
# 56    UCI          295         126        85         84     1502.857143
#
#     WaitlistedSATAvg  RejectedSATAvg  AcceptedECAvg  WaitlistedECAvg  \
# 56       1513.058824     1465.595238       6.115079         5.970588
#
#     RejectedECAvg  AcceptedEssayAvg  WaitlistedEssayAvg  RejectedEssayAvg  \
# 56       5.845238           4.89127                4.67          5.029762
#
#    COR-SAT-EC COR-SAT-ESSAY COR-EC-ESSAY
# 56   0.353865      0.100596     0.193821
#    School Applications Acceptances Waitlists Rejections  AcceptedSATAvg  \
# 57    UCM           23          20         1          2          1520.5
#
#     WaitlistedSATAvg  RejectedSATAvg  AcceptedECAvg  WaitlistedECAvg  \
# 57            1580.0          1195.0           6.05              6.5
#
#     RejectedECAvg  AcceptedEssayAvg  WaitlistedEssayAvg  RejectedEssayAvg  \
# 57            3.0              5.48                 4.2              5.35
#
#    COR-SAT-EC COR-SAT-ESSAY COR-EC-ESSAY
# 57   0.441398     -0.021479    -0.032149
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_4204\1988490707.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1

# %%
overall_df
# Out:
#                        School Applications Acceptances Waitlists Rejections  \
# 0                        UCLA          530         136       139        255
# 1                     HARVARD          506          67        77        362
# 2                        YALE          489          87        34        368
# 3                    STANFORD          534          69        22        443
# 4                NORTHWESTERN          417          89        56        272
# 5                    COLUMBIA          519         112        93        314
# 6                     CORNELL          585         153       105        327
# 7                    BERKELEY          473         143        60        270
# 8                        DUKE          396         100        49        247
# 9                   PRINCETON          424          77        42        305
# 10                       UCSD          280         147        68         65
# 11                        MIT          347         100        24        223
# 12                    CALTECH          166          28         9        129
# 13               GEORGIA TECH          317         129        58        130
# 14              JOHNS HOPKINS          208          54        36        118
# 15                 SWARTHMORE          135          29        31         75
# 16                  DARTMOUTH          257          52        49        156
# 17                        CMU          340          85       122        133
# 18                     PURDUE          270         184        24         62
# 19                       RICE          252          72        65        115
# 20                     POMONA          130          51        26         53
# 21                   WILLIAMS          145          45        36         64
# 22                 VANDERBILT          274          61        81        132
# 23                        NYU          326          98        58        170
# 24                      UPENN          618         218        72        328
# 25                      UMICH          451         171       137        143
# 26                      EMORY          196          66        52         78
# 27               CASE WESTERN          165          93        35         37
# 28                        USC          301         128         7        166
# 29                       UCSB          187         101        25         61
# 30                        UCD          200         122        46         32
# 31                       UCSC          113          84        16         13
# 32                        UCR           69          59         3          7
# 33                       UIUC          301         160        29        112
# 34          BOSTON UNIVERSITY          190          72        52         66
# 35             BOSTON COLLEGE          106          39        36         31
# 36                      WASHU          206          55        46        105
# 37                  UT-AUSTIN          172          74         4         94
# 38                  UT-DALLAS           30          28         0          2
# 39                    FORDHAM          121          96         7         18
# 40                    RUTGERS           84          78         1          5
# 41  San Jose State University           56          45         0         11
# 42              VIRGINIA TECH           76          44        17         15
# 43               NORTHEASTERN          434         167       113        154
# 44                 UW SEATTLE            0           0         0          0
# 45                    COLGATE           50          18         9         23
# 46                 UW MADISON           76          54         6         16
# 47                      TUFTS          191          48        26        117
# 48                     TULANE           68          17        24         27
# 49                HARVEY MUDD           56          13        13         30
# 50                   UCHICAGO          226          38        77        111
# 51            UNC CHAPEL HILL          101          56        11         34
# 52                        UVA          285         136        57         92
# 53          CLAREMONT MCKENNA           32           6         9         17
# 54              ARIZONA STATE          112          99         1         12
# 55                       TAMU           61          55         1          5
# 56                        UCI          295         126        85         84
# 57                        UCM           23          20         1          2
#
#     AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg  AcceptedECAvg  \
# 0      1497.794118       1516.978417     1489.058824       6.253676
# 1      1520.298507       1538.181818     1517.872928       7.037313
# 2      1514.482759       1535.882353     1514.646739       6.833333
# 3      1526.521739       1500.454545     1520.067720       6.681159
# 4      1513.033708       1538.928571     1510.919118       6.426966
# 5      1515.625000       1525.053763     1503.089172       6.683036
# 6      1509.803922       1533.904762     1502.385321       6.227451
# 7      1496.853147       1511.833333     1502.111111       6.410490
# 8      1524.800000       1532.040816     1508.785425       6.870000
# 9      1522.207792       1528.571429     1519.475410       7.038961
# 10     1490.340136       1493.088235     1492.307692       5.989796
# 11     1510.400000       1528.750000     1525.156951       6.175000
# 12     1534.285714       1520.000000     1525.658915       6.517857
# 13     1532.868217       1522.758621     1501.076923       6.541085
# 14     1493.333333       1521.388889     1498.644068       6.101852
# 15     1512.413793       1510.322581     1511.200000       6.086207
# 16     1517.307692       1528.775510     1497.371795       6.730769
# 17     1516.470588       1531.393443     1500.601504       6.517647
# 18     1507.989130       1508.750000     1484.516129       6.273370
# 19     1521.527778       1511.846154     1505.478261       6.493056
# 20     1460.588235       1474.230769     1498.113208       5.549020
# 21     1519.333333       1490.555556     1500.000000       6.722222
# 22     1519.508197       1537.160494     1503.787879       6.573770
# 23     1517.346939       1516.034483     1460.411765       6.280612
# 24     1490.779817       1532.222222     1506.768293       6.165138
# 25     1513.567251       1520.729927     1484.195804       6.232749
# 26     1499.545455       1510.000000     1485.128205       5.916667
# 27     1508.387097       1505.714286     1498.918919       5.833333
# 28     1502.031250       1532.857143     1489.759036       6.101562
# 29     1491.287129       1516.000000     1482.295082       6.039604
# 30     1487.868852       1503.913043     1473.125000       5.831967
# 31     1498.571429       1471.875000     1433.076923       6.160714
# 32     1474.576271       1556.666667     1465.714286       5.923729
# 33     1518.750000       1521.379310     1510.535714       6.304375
# 34     1495.416667       1484.423077     1464.848485       5.902778
# 35     1506.410256       1466.666667     1467.419355       5.884615
# 36     1515.454545       1525.000000     1508.857143       6.609091
# 37     1495.270270       1512.500000     1494.255319       6.067568
# 38     1510.357143               NaN     1385.000000       6.482143
# 39     1465.833333       1398.571429     1466.666667       5.651042
# 40     1486.666667       1450.000000     1518.000000       5.692308
# 41     1519.333333               NaN     1440.909091       6.100000
# 42     1468.409091       1447.058824     1444.666667       5.693182
# 43     1503.532934       1499.734513     1472.987013       5.772455
# 44             NaN               NaN             NaN            NaN
# 45     1483.888889       1466.666667     1487.391304       4.944444
# 46     1517.962963       1503.333333     1443.750000       5.912963
# 47     1498.125000       1521.153846     1495.897436       6.145833
# 48     1452.352941       1508.333333     1425.185185       6.500000
# 49     1502.307692       1558.461538     1529.333333       6.730769
# 50     1498.421053       1535.584416     1504.054054       6.578947
# 51     1516.785714       1464.545455     1480.000000       6.437500
# 52     1483.970588       1491.929825     1481.086957       5.801471
# 53     1436.666667       1495.555556     1479.411765       5.583333
# 54     1482.020202       1250.000000     1505.833333       5.348485
# 55     1505.090909       1510.000000     1480.000000       5.958182
# 56     1502.857143       1513.058824     1465.595238       6.115079
# 57     1520.500000       1580.000000     1195.000000       6.050000
#
#     WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg  WaitlistedEssayAvg  \
# 0          6.253957       5.850980          5.018015            5.100000
# 1          6.597403       6.282320          5.708955            5.610390
# 2          6.823529       6.213315          5.378161            5.500000
# 3          7.045455       6.418736          5.428986            4.690909
# 4          6.187500       6.258088          5.493258            5.262500
# 5          6.675269       6.143949          5.116964            5.325806
# 6          6.616190       6.171254          5.356209            5.380952
# 7          6.308333       6.062963          5.065035            5.301667
# 8          6.622449       6.082996          5.009000            4.755102
# 9          7.000000       6.327869          5.342857            5.590476
# 10         5.732353       5.884615          4.998980            5.191176
# 11         6.833333       6.348879          5.311000            5.741667
# 12         7.333333       6.701550          4.539286            5.466667
# 13         6.184483       5.446154          5.179070            4.904310
# 14         6.027778       6.300847          5.720370            5.388889
# 15         5.967742       5.846667          4.710345            5.348387
# 16         6.683673       6.164744          5.200000            5.683673
# 17         6.497541       6.056391          5.280000            5.414344
# 18         6.508333       5.387097          5.073913            5.070833
# 19         6.249231       6.046087          5.119444            5.344615
# 20         5.711538       5.613208          4.870588            5.615385
# 21         5.763889       5.687500          5.324444            5.763889
# 22         6.191358       6.109848          5.129508            5.274074
# 23         6.439655       5.826471          5.022449            5.065517
# 24         6.847222       6.195732          4.988073            5.423611
# 25         6.235036       5.835664          5.556725            5.144526
# 26         6.057692       5.455128          5.489394            5.055769
# 27         5.128571       5.364865          4.981720            4.825714
# 28         5.642857       6.068072          5.403906            4.457143
# 29         6.200000       5.483607          4.863366            4.796000
# 30         5.652174       5.843750          5.113934            4.829348
# 31         4.781250       5.884615          5.048810            4.000000
# 32         5.333333       5.142857          5.123729            2.566667
# 33         5.975862       5.995536          5.434687            5.434483
# 34         5.807692       5.401515          5.038889            5.432692
# 35         5.638889       5.629032          5.610256            5.027778
# 36         6.206522       6.014286          5.107273            4.995652
# 37         7.000000       6.042553          5.213514            4.600000
# 38              NaN       4.500000          5.275000                 NaN
# 39         6.357143       5.416667          5.368750            6.028571
# 40         1.000000       5.100000          5.115385            6.200000
# 41              NaN       5.863636          5.017778                 NaN
# 42         5.088235       4.366667          5.425000            5.505882
# 43         6.128319       5.600649          5.299401            4.905310
# 44              NaN            NaN               NaN                 NaN
# 45         5.166667       6.586957          4.722222            5.377778
# 46         5.250000       4.906250          4.687037            4.166667
# 47         5.557692       5.884615          4.879167            5.342308
# 48         5.520833       5.944444          4.611765            5.441667
# 49         6.230769       6.000000          4.200000            6.007692
# 50         6.240260       6.153153          5.568421            5.377922
# 51         5.954545       5.058824          5.375000            5.427273
# 52         5.561404       5.750000          5.523529            5.733333
# 53         4.944444       5.205882          4.916667            4.977778
# 54         1.000000       5.333333          5.188889            6.500000
# 55         6.500000       6.100000          5.238182            6.200000
# 56         5.970588       5.845238          4.891270            4.670000
# 57         6.500000       3.000000          5.480000            4.200000
#
#     RejectedEssayAvg COR-SAT-EC COR-SAT-ESSAY COR-EC-ESSAY
# 0           4.885490   0.364646      0.078477     0.166158
# 1           5.334807   0.196356      0.089163     0.068669
# 2           5.454891   0.208734      0.128943     0.076969
# 3           5.207901   0.266427      0.071241     0.038232
# 4           5.381250   0.154918      0.028023     0.153525
# 5           5.523885   0.284199       0.03337     0.054902
# 6           5.333639   0.214273      0.010087     0.089095
# 7           5.029259   0.353828      0.041427      0.14031
# 8           5.348178   0.247399      0.047991     0.093827
# 9           5.412131   0.251275       0.03719     0.043916
# 10          5.113846    0.33068      0.004146     0.148849
# 11          5.299776   0.248841      0.132642     0.121864
# 12          5.235271   0.289057     -0.051728     0.033052
# 13          4.977692   0.276164     -0.013391     0.071957
# 14          5.117797   0.279297     -0.020587     0.036201
# 15          5.630667   0.064612      0.245387     0.052421
# 16          5.556410   0.311752      0.010289     0.092985
# 17          5.024812   0.224479     -0.028426     0.141945
# 18          4.850000   0.230769     -0.060848     0.204773
# 19          5.451304   0.338514      0.131598     0.155226
# 20          5.128302   0.306212      0.229854     0.158067
# 21          5.210938   0.213561      0.038943     0.096891
# 22          5.494697   0.151013      0.011676     0.130539
# 23          5.198529    0.26368       0.07972        0.175
# 24          5.243293    0.29967      0.038778      0.13662
# 25          4.933566   0.223591     -0.027483     0.126905
# 26          5.293590   0.217189      0.186423     0.208236
# 27          4.429730   0.131876      0.075491      0.00759
# 28          4.951205   0.337595      0.065248     0.212596
# 29          5.113115   0.317051      0.056074     0.167294
# 30          5.065625   0.359325     -0.128064     0.206271
# 31          4.038462    0.21167      0.090918     0.325196
# 32          5.314286   0.420185      0.045004     0.256665
# 33          4.671429   0.257655     -0.107113     0.162302
# 34          5.328788   0.254032      0.109587     0.158654
# 35          5.003226   0.258074      0.196932     0.032557
# 36          5.014286   0.245376      -0.01318      0.10622
# 37          5.409574   0.299645      0.037429     0.070128
# 38          3.850000   0.140418      0.117615     0.508406
# 39          4.711111   0.281452      0.024831     0.244701
# 40          4.580000   0.269346       0.03926     0.179458
# 41          5.490909   0.348817      0.020658     0.113885
# 42          4.753333   0.207112       0.00023    -0.017798
# 43          5.175974   0.165862      0.089985     0.093418
# 44               NaN        NaN           NaN          NaN
# 45          5.395652   0.108622     -0.257148      0.07818
# 46          5.443750   0.049555     -0.237273     0.165938
# 47          5.329915   0.034095      0.052532     0.086407
# 48          4.803704   0.239678      0.039789     0.063745
# 49          4.543333  -0.121382      0.008099     0.249004
# 50          5.568468   0.268404      0.108723     0.162892
# 51          5.370588   0.182044      0.034837     0.086517
# 52          4.815217   0.284343     -0.001789    -0.028024
# 53          4.958824   0.150568     -0.027074     0.164606
# 54          5.275000   0.209317      -0.04406     0.273382
# 55          3.760000   0.179346     -0.020328     0.229618
# 56          5.029762   0.353865      0.100596     0.193821
# 57          5.350000   0.441398     -0.021479    -0.032149
