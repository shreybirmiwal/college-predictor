# %%
import pandas as pd

df = pd.read_csv('CLEAN.csv')
df = df.drop(columns=['Note'])
df
# Out:
#      Gender   Race Residence  Income School Type Hooks         Major   SAT  \
# 0         M  ASIAN        MI     Low          -1  NONE            CS  1440
# 1     OTHER  ASIAN        IN    High          -1  NONE            CS  1390
# 2         F  ASIAN        MA    High      PUBLIC  NONE  NEUROSCIENCE  1580
# 3         M  WHITE        IN     Low          -1   URM            CS  1580
# 4         F  ASIAN        OR  Middle      PUBLIC  NONE            CS  1580
# ...     ...    ...       ...     ...         ...   ...           ...   ...
# 1479      M  ASIAN        GA  Middle      PUBLIC  LGBT           BIO  1580
# 1480      F  ASIAN        CA    High      PUBLIC  NONE            CS  1590
# 1481      M  ASIAN        CA  Middle      PUBLIC  NONE           ENG  1240
# 1482      M  ASIAN        CA     Low      PUBLIC  NONE            CS  1580
# 1483      M  ASIAN        FL    High      PUBLIC  NONE            CS  1560
#
#       EC-AWARDS  ESSAY-LOR-INTERVIEW  \
# 0           2.0                  4.5
# 1           5.5                  4.5
# 2           7.5                  7.5
# 3           5.5                  1.5
# 4           7.5                  4.7
# ...         ...                  ...
# 1479        5.0                  3.5
# 1480        7.5                  3.5
# 1481        3.0                  6.5
# 1482        6.5                  7.5
# 1483        8.5                  8.5
#
#                                             Acceptances  \
# 0                                           ['*PURDUE']
# 1                                         ['*STANFORD']
# 2     ['*UCLA', '*HARVARD', '*YALE', '*COLUMBIA', '*...
# 3     ['*GEORGIA TECH', '*UT-AUSTIN', '*ARIZONA STAT...
# 4                              ['*CORNELL', '*RUTGERS']
# ...                                                 ...
# 1479                         ['*NYU', '*UMICH', '*USC']
# 1480       ['*DUKE', '*UCSD', '*UIUC', '*NORTHEASTERN']
# 1481                                           ['*UCI']
# 1482  ['*UCLA', '*PURDUE', '*POMONA', '*ARIZONA STAT...
# 1483  ['*UCLA', '*UCSD', '*GEORGIA TECH', '*PURDUE',...
#
#                                               Waitlists  \
# 0                           ['*GEORGIA TECH', '*UMICH']
# 1                                                    []
# 2                                            ['*UPENN']
# 3                             ['*HARVARD', '*UCHICAGO']
# 4                                                    []
# ...                                                 ...
# 1479                    ['*JOHNS HOPKINS', '*UCHICAGO']
# 1480                          ['*CMU', '*UCSB', '*UCI']
# 1481                                        ['*POMONA']
# 1482  ['*UCLA', '*STANFORD', '*CORNELL', '*GEORGIA T...
# 1483  ['*COLUMBIA', '*CORNELL', '*BERKELEY', '*PRINC...
#
#                                              Rejections
# 0                            ['*UIUC', '*NORTHEASTERN']
# 1                                          ['*CALTECH']
# 2                            ['*STANFORD', '*COLUMBIA']
# 3     ['*UCLA', '*NORTHWESTERN', '*UMICH', '*EMORY',...
# 4                                          ['*CORNELL']
# ...                                                 ...
# 1479  ['*HARVARD', '*YALE', '*BROWN', '*STANFORD', '...
# 1480  ['*UCLA', '*HARVARD', '*BROWN', '*STANFORD', '...
# 1481                             ['*UCLA', '*BERKELEY']
# 1482  ['*HARVARD', '*YALE', '*COLUMBIA', '*MIT', '*C...
# 1483      ['*HARVARD', '*STANFORD', '*MIT', '*CALTECH']
#
# [1484 rows x 13 columns]

# %%
colleges = [ '*UCLA', '*HARVARD', '*YALE'
, '*STANFORD', '*NORTHWESTERN', '*COLUMBIA', '*CORNELL', '*BERKELEY'
, '*DUKE', '*PRINCETON', '*UCSD', '*MIT', '*CALTECH', '*GEORGIA TECH'
, '*JOHNS HOPKINS', '*SWARTHMORE', '*DARTMOUTH', '*CMU', '*PURDUE'
, '*RICE', '*POMONA', '*WILLIAMS', '*VANDERBILT', '*NYU', '*UPENN'
, '*UMICH', '*EMORY', '*CASE WESTERN', '*USC', '*UCSB', '*UCD', '*UCSC'
, '*UCR', '*UIUC', '*BOSTON UNIVERSITY', '*BOSTON COLLEGE', '*WASHU'
, '*UT-AUSTIN', '*UT-DALLAS', '*FORDHAM', '*RUTGERS', '*San Jose State University'
, '*VIRGINIA TECH', '*NORTHEASTERN', '*UW SEATTLE', '*COLGATE', '*UW MADISON'
, '*TUFTS', '*TULANE', '*HARVEY MUDD', '*UCHICAGO', '*UNC CHAPEL HILL'
, '*UVA', '*CLAREMONT MCKENNA', '*ARIZONA STATE', '*TAMU', '*UCI', '*UCM']
# *BROWN
# *STANFORD
# *NORTHWESTERN
# *COLUMBIA
# *CORNELL
# *BERKELEY
# *DUKE
# *PRINCETON
# *UCSD
# *MIT
# *CALTECH
# *GEORGIA TECH
# *JOHNS HOPKINS
# *SWARTHMORE
# *DARTMOUTH
# *CMU
# *PURDUE
# *RICE
# *POMONA
# *WILLIAMS
# *VANDERBILT
# *NYU
# *UPENN
# *UMICH
# *EMORY
# *CASE WESTERN
# *USC
# *UCSB
# *UCD
# *UCSC
# *UCR
# *UIUC
# *BOSTON UNIVERSITY
# *BOSTON COLLEGE
# *WASHU
# *UT-AUSTIN
# *UT-DALLAS
# *FORDHAM
# *RUTGERS
# *San Jose State University
# *VIRGINIA TECH
# *NORTHEASTERN
# *UW SEATTLE
# *COLGATE
# *UW MADISON
# *TUFTS
# *TULANE
# *HARVEY MUDD
# *UCHICAGO
# *UNC CHAPEL HILL
# *UVA
# *CLAREMONT MCKENNA
# *ARIZONA STATE
# *TAMU
# *UCI
# *UCM

# %%
def basicAnalysis(df, college):
    
    ret = []
    ret.append(college)
    ret.append(len(df))
    ret.append(len(df[df['Decision'] == 0]))

    return [college, len(df), len(df[df['Decision'] == 0]), len(df[df['Decision'] == 1]), len(df[df['Decision'] == 2]), 'AcceptedSATAvg', 'WaitlistedSATAvg', 'RejectedSATAvg', 'AcceptedECAvg', 'WaitlistedECAvg', 'RejectedECAvg', 'AcceptedEssayAvg', 'WaitlistedEssayAvg', 'RejectedEssayAvg']
    #return ['School', 'Applications', 'Acceptances', 'Waitlists', 'Rejections', 'AcceptedSATAvg', 'WaitlistedSATAvg', 'RejectedSATAvg', 'AcceptedECAvg', 'WaitlistedECAvg', 'RejectedECAvg', 'AcceptedEssayAvg', 'WaitlistedEssayAvg', 'RejectedEssayAvg']

# %%
overall_df = pd.DataFrame(columns=['School', 'Applications', 'Acceptances', 'Waitlists', 'Rejections', 'AcceptedSATAvg', 'WaitlistedSATAvg', 'RejectedSATAvg', 'AcceptedECAvg', 'WaitlistedECAvg', 'RejectedECAvg', 'AcceptedEssayAvg', 'WaitlistedEssayAvg', 'RejectedEssayAvg'])

for college in colleges:
    college = college.removeprefix('*')
    
    accepted = df[df['Acceptances'].str.contains(college, regex=False)]
    accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
    accepted['Decision'] = 0

    rejected = df[df['Rejections'].str.contains(college, regex=False)]
    rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
    rejected['Decision'] = 2
    
    waitlisted = df[df['Waitlists'].str.contains(college, regex=False)]
    waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
    waitlisted['Decision'] = 1

    college_df = pd.concat([accepted, rejected, waitlisted])

    
    #create folder if it doesnt exist
    import os
    if not os.path.exists(f'res/{college}'):
        os.makedirs(f'res/{college}')


    #basic analysis
    overall_df.loc[len(overall_df.index)] = basicAnalysis(college_df, college)
    
    # save the dataset
    college_df.to_csv(f'res/{college}/dataset.csv', index=False)
# Out:
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   accepted['Decision'] = 0
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rejected['Decision'] = 2
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted.drop(columns=['Rejections', 'Acceptances', 'Waitlists'], inplace=True)
# C:\Users\shrey\AppData\Local\Temp\ipykernel_17560\2653864006.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   waitlisted['Decision'] = 1

# %%
overall_df
# Out:
#                        School  Applications  Acceptances  Waitlists  \
# 0                        UCLA           530          136        139
# 1                     HARVARD           506           67         77
# 2                        YALE           489           87         34
# 3                    STANFORD           534           69         22
# 4                NORTHWESTERN           417           89         56
# 5                    COLUMBIA           519          112         93
# 6                     CORNELL           585          153        105
# 7                    BERKELEY           473          143         60
# 8                        DUKE           396          100         49
# 9                   PRINCETON           424           77         42
# 10                       UCSD           280          147         68
# 11                        MIT           347          100         24
# 12                    CALTECH           166           28          9
# 13               GEORGIA TECH           317          129         58
# 14              JOHNS HOPKINS           208           54         36
# 15                 SWARTHMORE           135           29         31
# 16                  DARTMOUTH           257           52         49
# 17                        CMU           340           85        122
# 18                     PURDUE           270          184         24
# 19                       RICE           252           72         65
# 20                     POMONA           130           51         26
# 21                   WILLIAMS           145           45         36
# 22                 VANDERBILT           274           61         81
# 23                        NYU           326           98         58
# 24                      UPENN           618          218         72
# 25                      UMICH           451          171        137
# 26                      EMORY           196           66         52
# 27               CASE WESTERN           165           93         35
# 28                        USC           301          128          7
# 29                       UCSB           187          101         25
# 30                        UCD           200          122         46
# 31                       UCSC           113           84         16
# 32                        UCR            69           59          3
# 33                       UIUC           301          160         29
# 34          BOSTON UNIVERSITY           190           72         52
# 35             BOSTON COLLEGE           106           39         36
# 36                      WASHU           206           55         46
# 37                  UT-AUSTIN           172           74          4
# 38                  UT-DALLAS            30           28          0
# 39                    FORDHAM           121           96          7
# 40                    RUTGERS            84           78          1
# 41  San Jose State University            56           45          0
# 42              VIRGINIA TECH            76           44         17
# 43               NORTHEASTERN           434          167        113
# 44                 UW SEATTLE             0            0          0
# 45                    COLGATE            50           18          9
# 46                 UW MADISON            76           54          6
# 47                      TUFTS           191           48         26
# 48                     TULANE            68           17         24
# 49                HARVEY MUDD            56           13         13
# 50                   UCHICAGO           226           38         77
# 51            UNC CHAPEL HILL           101           56         11
# 52                        UVA           285          136         57
# 53          CLAREMONT MCKENNA            32            6          9
# 54              ARIZONA STATE           112           99          1
# 55                       TAMU            61           55          1
# 56                        UCI           295          126         85
# 57                        UCM            23           20          1
#
#     Rejections  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg  \
# 0          255  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 1          362  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 2          368  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 3          443  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 4          272  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 5          314  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 6          327  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 7          270  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 8          247  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 9          305  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 10          65  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 11         223  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 12         129  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 13         130  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 14         118  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 15          75  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 16         156  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 17         133  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 18          62  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 19         115  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 20          53  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 21          64  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 22         132  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 23         170  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 24         328  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 25         143  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 26          78  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 27          37  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 28         166  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 29          61  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 30          32  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 31          13  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 32           7  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 33         112  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 34          66  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 35          31  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 36         105  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 37          94  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 38           2  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 39          18  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 40           5  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 41          11  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 42          15  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 43         154  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 44           0  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 45          23  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 46          16  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 47         117  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 48          27  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 49          30  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 50         111  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 51          34  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 52          92  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 53          17  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 54          12  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 55           5  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 56          84  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
# 57           2  AcceptedSATAvg  WaitlistedSATAvg  RejectedSATAvg
#
#     AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg  \
# 0   AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 1   AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 2   AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 3   AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 4   AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 5   AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 6   AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 7   AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 8   AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 9   AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 10  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 11  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 12  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 13  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 14  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 15  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 16  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 17  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 18  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 19  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 20  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 21  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 22  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 23  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 24  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 25  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 26  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 27  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 28  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 29  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 30  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 31  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 32  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 33  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 34  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 35  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 36  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 37  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 38  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 39  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 40  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 41  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 42  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 43  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 44  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 45  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 46  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 47  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 48  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 49  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 50  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 51  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 52  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 53  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 54  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 55  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 56  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
# 57  AcceptedECAvg  WaitlistedECAvg  RejectedECAvg  AcceptedEssayAvg
#
#     WaitlistedEssayAvg  RejectedEssayAvg
# 0   WaitlistedEssayAvg  RejectedEssayAvg
# 1   WaitlistedEssayAvg  RejectedEssayAvg
# 2   WaitlistedEssayAvg  RejectedEssayAvg
# 3   WaitlistedEssayAvg  RejectedEssayAvg
# 4   WaitlistedEssayAvg  RejectedEssayAvg
# 5   WaitlistedEssayAvg  RejectedEssayAvg
# 6   WaitlistedEssayAvg  RejectedEssayAvg
# 7   WaitlistedEssayAvg  RejectedEssayAvg
# 8   WaitlistedEssayAvg  RejectedEssayAvg
# 9   WaitlistedEssayAvg  RejectedEssayAvg
# 10  WaitlistedEssayAvg  RejectedEssayAvg
# 11  WaitlistedEssayAvg  RejectedEssayAvg
# 12  WaitlistedEssayAvg  RejectedEssayAvg
# 13  WaitlistedEssayAvg  RejectedEssayAvg
# 14  WaitlistedEssayAvg  RejectedEssayAvg
# 15  WaitlistedEssayAvg  RejectedEssayAvg
# 16  WaitlistedEssayAvg  RejectedEssayAvg
# 17  WaitlistedEssayAvg  RejectedEssayAvg
# 18  WaitlistedEssayAvg  RejectedEssayAvg
# 19  WaitlistedEssayAvg  RejectedEssayAvg
# 20  WaitlistedEssayAvg  RejectedEssayAvg
# 21  WaitlistedEssayAvg  RejectedEssayAvg
# 22  WaitlistedEssayAvg  RejectedEssayAvg
# 23  WaitlistedEssayAvg  RejectedEssayAvg
# 24  WaitlistedEssayAvg  RejectedEssayAvg
# 25  WaitlistedEssayAvg  RejectedEssayAvg
# 26  WaitlistedEssayAvg  RejectedEssayAvg
# 27  WaitlistedEssayAvg  RejectedEssayAvg
# 28  WaitlistedEssayAvg  RejectedEssayAvg
# 29  WaitlistedEssayAvg  RejectedEssayAvg
# 30  WaitlistedEssayAvg  RejectedEssayAvg
# 31  WaitlistedEssayAvg  RejectedEssayAvg
# 32  WaitlistedEssayAvg  RejectedEssayAvg
# 33  WaitlistedEssayAvg  RejectedEssayAvg
# 34  WaitlistedEssayAvg  RejectedEssayAvg
# 35  WaitlistedEssayAvg  RejectedEssayAvg
# 36  WaitlistedEssayAvg  RejectedEssayAvg
# 37  WaitlistedEssayAvg  RejectedEssayAvg
# 38  WaitlistedEssayAvg  RejectedEssayAvg
# 39  WaitlistedEssayAvg  RejectedEssayAvg
# 40  WaitlistedEssayAvg  RejectedEssayAvg
# 41  WaitlistedEssayAvg  RejectedEssayAvg
# 42  WaitlistedEssayAvg  RejectedEssayAvg
# 43  WaitlistedEssayAvg  RejectedEssayAvg
# 44  WaitlistedEssayAvg  RejectedEssayAvg
# 45  WaitlistedEssayAvg  RejectedEssayAvg
# 46  WaitlistedEssayAvg  RejectedEssayAvg
# 47  WaitlistedEssayAvg  RejectedEssayAvg
# 48  WaitlistedEssayAvg  RejectedEssayAvg
# 49  WaitlistedEssayAvg  RejectedEssayAvg
# 50  WaitlistedEssayAvg  RejectedEssayAvg
# 51  WaitlistedEssayAvg  RejectedEssayAvg
# 52  WaitlistedEssayAvg  RejectedEssayAvg
# 53  WaitlistedEssayAvg  RejectedEssayAvg
# 54  WaitlistedEssayAvg  RejectedEssayAvg
# 55  WaitlistedEssayAvg  RejectedEssayAvg
# 56  WaitlistedEssayAvg  RejectedEssayAvg
# 57  WaitlistedEssayAvg  RejectedEssayAvg
